# %% [markdown]
# <a href="https://colab.research.google.com/github/youngchul-sung/three-minutes-keras/blob/master/ex9_1_applications_augmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 2.x

"""
CH 9.1 Applications/Image Augmentation
"""
from sklearn import model_selection
from tensorflow import keras
from tensorflow.keras import datasets
# Out:
# TensorFlow 2.x selected.

# %%
"""
skeras.py
"""

import numpy as np
import matplotlib.pyplot as plt
import os

import matplotlib

def save_history_history(fname, history_history, fold=''):
    np.save(os.path.join(fold, fname), history_history)


def load_history_history(fname, fold=''):
    history_history = np.load(os.path.join(fold, fname)).item(0)
    return history_history


def plot_acc(history, title=None):
    # summarize history for accuracy
    if not isinstance(history, dict):
        history = history.history

    plt.plot(history['accuracy'])
    plt.plot(history['val_accuracy'])
    if title is not None:
        plt.title(title)
    plt.ylabel('Accracy')
    plt.xlabel('Epoch')
    plt.legend(['Training data', 'Validation data'], loc=0)
    # plt.show()


def plot_loss(history, title=None):
    # summarize history for loss
    if not isinstance(history, dict):
        history = history.history

    plt.plot(history['loss'])
    plt.plot(history['val_loss'])
    if title is not None:
        plt.title(title)
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Training data', 'Validation data'], loc=0)
    # plt.show()


def plot_history(history):
    plt.figure(figsize=(15, 5))
    plt.subplot(1, 2, 1)
    plot_acc(history)
    plt.subplot(1, 2, 2)
    plot_loss(history)

    
def plot_loss_acc(history):
    plot_loss(history, '(a) Loss trajectory')
    plt.show()            
    plot_acc(history, '(b) Accracy trajectory')
    plt.show()
    
    
def plot_acc_loss(history):
    plot_acc(history, '(a) Accracy trajectory')
    plt.show()
    plot_loss(history, '(b) Loss trajectory')
    plt.show()

# %%
"""
sfile.py
"""

import datetime
import uuid
import os


def unique_filename(type='uuid'):
    if type == 'datetime':
        filename = datetime.datetime.now().strftime("%y%m%d_%H%M%S")
    else:  # type == "uuid"
        filename = str(uuid.uuid4())
    return filename


def makenewfold(prefix='output_', type='datetime'):
    suffix = unique_filename('datetime')
    foldname = 'output_' + suffix
    os.makedirs(foldname)
    return foldname

# %%
"""
aicnn.py 

CNN for image classification
- MIT License
- Author: Sungjin Kim
"""
from sklearn import model_selection, metrics
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import matplotlib.pyplot as plt
import os

from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras import optimizers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout



class CNN(Model):
    def __init__(model, nb_classes, in_shape=None):
        super().__init__()
        model.nb_classes = nb_classes
        model.in_shape = in_shape
        model.build_model()
        super().__init__(model.x, model.y)
        model.compile()

    def build_model(model):
        nb_classes = model.nb_classes
        in_shape = model.in_shape

        x = Input(in_shape)

        h = Conv2D(32, kernel_size=(3, 3), activation='relu',
                   input_shape=in_shape)(x)
        h = Conv2D(64, (3, 3), activation='relu')(h)
        h = MaxPooling2D(pool_size=(2, 2))(h)
        h = Dropout(0.25)(h)
        h = Flatten()(h)
        z_cl = h

        h = Dense(128, activation='relu')(h)
        h = Dropout(0.5)(h)
        z_fl = h

        y = Dense(nb_classes, activation='softmax', name='preds')(h)

        model.cl_part = Model(x, z_cl)
        model.fl_part = Model(x, z_fl)

        model.x, model.y = x, y

    def compile(model):
        Model.compile(model, loss='categorical_crossentropy',
                      optimizer=optimizers.Adadelta(learning_rate=1.0), metrics=['accuracy'])


class DataSet:
    def __init__(self, X, y, nb_classes, scaling=True, test_size=0.2, random_state=0):
        """
        X is originally vector. Hence, it will be transformed
        to 2D images with a channel (i.e, 3D).
        """
        self.X = X
        self.add_channels()

        X = self.X
        # the data, shuffled and split between train and test sets
        X_train, X_test, y_train, y_test = model_selection.train_test_split(
            X, y, test_size=0.2, random_state=random_state)

        print(X_train.shape, y_train.shape)

        X_train = X_train.astype('float32')
        X_test = X_test.astype('float32')

        if scaling:
            # scaling to have (0, 1) for each feature (each pixel)
            scaler = MinMaxScaler()
            n = X_train.shape[0]
            X_train = scaler.fit_transform(
                X_train.reshape(n, -1)).reshape(X_train.shape)
            n = X_test.shape[0]
            X_test = scaler.transform(
                X_test.reshape(n, -1)).reshape(X_test.shape)
            self.scaler = scaler

        print('X_train shape:', X_train.shape)
        print(X_train.shape[0], 'train samples')
        print(X_test.shape[0], 'test samples')

        # convert class vectors to binary class matrices
        Y_train = keras.utils.to_categorical(y_train, nb_classes)
        Y_test = keras.utils.to_categorical(y_test, nb_classes)

        self.X_train, self.X_test = X_train, X_test
        self.Y_train, self.Y_test = Y_train, Y_test
        self.y_train, self.y_test = y_train, y_test
        # self.input_shape = input_shape

    def add_channels(self):
        X = self.X

        if len(X.shape) == 3:
            N, img_rows, img_cols = X.shape

            if K.image_dim_ordering() == 'th':
                X = X.reshape(X.shape[0], 1, img_rows, img_cols)
                input_shape = (1, img_rows, img_cols)
            else:
                X = X.reshape(X.shape[0], img_rows, img_cols, 1)
                input_shape = (img_rows, img_cols, 1)
        else:
            input_shape = X.shape[1:]  # channel is already included.

        self.X = X
        self.input_shape = input_shape


class aicnn_Machine():
    def __init__(self, X, y, nb_classes=2, fig=True):
        self.nb_classes = nb_classes
        self.set_data(X, y)
        self.set_model()
        self.fig = fig

    def set_data(self, X, y):
        nb_classes = self.nb_classes
        self.data = DataSet(X, y, nb_classes)
        print('data.input_shape', self.data.input_shape)

    def set_model(self):
        nb_classes = self.nb_classes
        data = self.data
        self.model = CNN(nb_classes=nb_classes, in_shape=data.input_shape)
        # cnn_lenet(nb_classes=nb_classes, in_shape=data.input_shape)

    def fit(self, epochs=10, batch_size=128, verbose=1):
        data = self.data
        model = self.model

        history = model.fit(data.X_train, data.Y_train, batch_size=batch_size, epochs=epochs,
                            verbose=verbose, validation_data=(data.X_test, data.Y_test))
        return history

    def run(self, epochs=100, batch_size=128, verbose=1):
        data = self.data
        model = self.model
        fig = self.fig

        history = self.fit(epochs=epochs,
                           batch_size=batch_size, verbose=verbose)

        score = model.evaluate(data.X_test, data.Y_test, verbose=0)

        print('Confusion matrix')
        Y_test_pred = model.predict(data.X_test, verbose=0)
        y_test_pred = np.argmax(Y_test_pred, axis=1)
        print(metrics.confusion_matrix(data.y_test, y_test_pred))

        print('Test score:', score[0])
        print('Test accuracy:', score[1])

        # Save results
        suffix = unique_filename('datatime')
        foldname = 'output_' + suffix
        os.makedirs(foldname)
        save_history_history(
            'history_history.npy', history.history, fold=foldname)
        model.save_weights(os.path.join(foldname, 'dl_model.h5'))
        print('Output results are saved in', foldname)
          
        if fig:
            plot_acc_loss(history)

        self.history = history

        return foldname

# %%
"""
aigen.py

Generator code for the image data augmentation
- MIT Licence
- Author: Sungjin Kim
"""
from tensorflow.keras.preprocessing.image import ImageDataGenerator


class aigen_Machine_Generator(aicnn_Machine):
    def __init__(self, X, y, nb_classes=2, steps_per_epoch=5, fig=True,
                 gen_param_dict=None):
        super().__init__(X, y, nb_classes=nb_classes, fig=fig)
        self.set_generator(steps_per_epoch=steps_per_epoch,
                           gen_param_dict=gen_param_dict)

    def set_generator(self, steps_per_epoch=10, gen_param_dict=None):
        if gen_param_dict is not None:
            self.generator = ImageDataGenerator(**gen_param_dict)
        else:
            self.generator = ImageDataGenerator()

        print(self.data.X_train.shape)

        self.generator.fit(self.data.X_train, seed=0)
        self.steps_per_epoch = steps_per_epoch

    def fit(self, epochs=10, batch_size=64, verbose=1):
        model = self.model
        data = self.data
        generator = self.generator
        steps_per_epoch = self.steps_per_epoch

        history = model.fit_generator(
            generator.flow(data.X_train, data.Y_train, batch_size=batch_size),
            epochs=epochs, steps_per_epoch=steps_per_epoch,
            validation_data=(data.X_test, data.Y_test))

        return history

# %%
assert keras.backend.image_data_format() == 'channels_last'

def get_Xy():
    (x_train, y_train), (x_test, y_test) = datasets.cifar10.load_data()
    _, X, _, y = model_selection.train_test_split(x_train, y_train, test_size=0.02)
    X = X.astype(float)

    return X, y


class Machine(aigen_Machine_Generator):
    def __init__(self, X, y, gen_param_dict):
        super().__init__(np.random.rand(10, 32, 32, 3), np.random.rand(10, 1))
        (x_train, y_train), (x_test, y_test) = datasets.cifar10.load_data()
        _, X, _, y = model_selection.train_test_split(x_train, y_train, test_size=0.02)
        X = X.astype(float)

        gen_param_dict = {'rotation_range': 10}

        super().__init__(X, y, nb_classes=10, gen_param_dict=gen_param_dict)


def main():
    X, y = get_Xy()
    gen_param_dict = {'rotation_range': 10}

    m = Machine(X, y, gen_param_dict)
    m.run()


if __name__ == '__main__':
    main()
# Out:
# (8, 32, 32, 3) (8, 1)
# X_train shape: (8, 32, 32, 3)
# 8 train samples
# 2 test samples
# data.input_shape (32, 32, 3)
# (8, 32, 32, 3)
# (800, 32, 32, 3) (800, 1)
# X_train shape: (800, 32, 32, 3)
# 800 train samples
# 200 test samples
# data.input_shape (32, 32, 3)
# (800, 32, 32, 3)
# WARNING:tensorflow:From <ipython-input-5-b6532af9dcae>:38: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 5 steps, validate on 200 samples
# Epoch 1/100
# 5/5 [==============================] - 3s 548ms/step - loss: 2.3547 - accuracy: 0.0919 - val_loss: 2.2919 - val_accuracy: 0.0950
# Epoch 2/100
# 5/5 [==============================] - 2s 449ms/step - loss: 2.2918 - accuracy: 0.1379 - val_loss: 2.2878 - val_accuracy: 0.1400
# Epoch 3/100
# 5/5 [==============================] - 2s 451ms/step - loss: 2.2553 - accuracy: 0.1838 - val_loss: 2.2620 - val_accuracy: 0.1150
# Epoch 4/100
# 5/5 [==============================] - 3s 516ms/step - loss: 2.2657 - accuracy: 0.1594 - val_loss: 2.2550 - val_accuracy: 0.1700
# Epoch 5/100
# 5/5 [==============================] - 3s 502ms/step - loss: 2.2061 - accuracy: 0.2016 - val_loss: 2.1451 - val_accuracy: 0.2250
# Epoch 6/100
# 5/5 [==============================] - 2s 449ms/step - loss: 2.1557 - accuracy: 0.2371 - val_loss: 2.3988 - val_accuracy: 0.1200
# Epoch 7/100
# 5/5 [==============================] - 2s 448ms/step - loss: 2.2125 - accuracy: 0.1967 - val_loss: 2.2187 - val_accuracy: 0.1450
# Epoch 8/100
# 5/5 [==============================] - 2s 451ms/step - loss: 2.1479 - accuracy: 0.2077 - val_loss: 2.0808 - val_accuracy: 0.2450
# Epoch 9/100
# 5/5 [==============================] - 2s 447ms/step - loss: 2.1699 - accuracy: 0.1967 - val_loss: 2.1193 - val_accuracy: 0.2250
# Epoch 10/100
# 5/5 [==============================] - 2s 448ms/step - loss: 2.0395 - accuracy: 0.2647 - val_loss: 2.1199 - val_accuracy: 0.2550
# Epoch 11/100
# 5/5 [==============================] - 2s 452ms/step - loss: 2.0605 - accuracy: 0.2537 - val_loss: 2.0609 - val_accuracy: 0.2100
# Epoch 12/100
# 5/5 [==============================] - 2s 446ms/step - loss: 1.9364 - accuracy: 0.2904 - val_loss: 2.0072 - val_accuracy: 0.2200
# Epoch 13/100
# 5/5 [==============================] - 3s 510ms/step - loss: 2.0005 - accuracy: 0.2656 - val_loss: 2.4019 - val_accuracy: 0.1100
# Epoch 14/100
# 5/5 [==============================] - 2s 445ms/step - loss: 2.0655 - accuracy: 0.2904 - val_loss: 1.9364 - val_accuracy: 0.3350
# Epoch 15/100
# 5/5 [==============================] - 2s 448ms/step - loss: 1.9352 - accuracy: 0.2960 - val_loss: 1.9736 - val_accuracy: 0.3050
# Epoch 16/100
# 5/5 [==============================] - 2s 450ms/step - loss: 1.7954 - accuracy: 0.3529 - val_loss: 2.0903 - val_accuracy: 0.2650
# Epoch 17/100
# 5/5 [==============================] - 2s 452ms/step - loss: 1.8084 - accuracy: 0.3585 - val_loss: 1.9245 - val_accuracy: 0.2950
# Epoch 18/100
# 5/5 [==============================] - 2s 447ms/step - loss: 1.6783 - accuracy: 0.3676 - val_loss: 1.9928 - val_accuracy: 0.2500
# Epoch 19/100
# 5/5 [==============================] - 2s 448ms/step - loss: 1.8265 - accuracy: 0.3676 - val_loss: 1.8207 - val_accuracy: 0.3150
# Epoch 20/100
# 5/5 [==============================] - 2s 452ms/step - loss: 1.6092 - accuracy: 0.4044 - val_loss: 1.8610 - val_accuracy: 0.3050
# Epoch 21/100
# 5/5 [==============================] - 2s 447ms/step - loss: 1.6112 - accuracy: 0.4375 - val_loss: 1.9745 - val_accuracy: 0.2900
# Epoch 22/100
# 5/5 [==============================] - 2s 453ms/step - loss: 1.5199 - accuracy: 0.4835 - val_loss: 1.8971 - val_accuracy: 0.3600
# Epoch 23/100
# 5/5 [==============================] - 3s 508ms/step - loss: 1.9569 - accuracy: 0.3250 - val_loss: 1.8329 - val_accuracy: 0.3750
# Epoch 24/100
# 5/5 [==============================] - 3s 513ms/step - loss: 1.5530 - accuracy: 0.4891 - val_loss: 1.7549 - val_accuracy: 0.3850
# Epoch 25/100
# 5/5 [==============================] - 3s 509ms/step - loss: 1.5755 - accuracy: 0.4375 - val_loss: 1.9190 - val_accuracy: 0.3100
# Epoch 26/100
# 5/5 [==============================] - 2s 450ms/step - loss: 1.3904 - accuracy: 0.5110 - val_loss: 1.6765 - val_accuracy: 0.4250
# Epoch 27/100
# 5/5 [==============================] - 2s 450ms/step - loss: 1.7448 - accuracy: 0.3860 - val_loss: 2.0287 - val_accuracy: 0.2650
# Epoch 28/100
# 5/5 [==============================] - 2s 447ms/step - loss: 1.4221 - accuracy: 0.5110 - val_loss: 1.6926 - val_accuracy: 0.4150
# Epoch 29/100
# 5/5 [==============================] - 3s 508ms/step - loss: 1.3128 - accuracy: 0.5359 - val_loss: 1.6758 - val_accuracy: 0.4250
# Epoch 30/100
# 5/5 [==============================] - 3s 504ms/step - loss: 1.3133 - accuracy: 0.5531 - val_loss: 1.7487 - val_accuracy: 0.4050
# Epoch 31/100
# 5/5 [==============================] - 3s 513ms/step - loss: 1.2743 - accuracy: 0.5844 - val_loss: 1.7625 - val_accuracy: 0.3850
# Epoch 32/100
# 5/5 [==============================] - 2s 454ms/step - loss: 1.1411 - accuracy: 0.5956 - val_loss: 1.7181 - val_accuracy: 0.4150
# Epoch 33/100
# 5/5 [==============================] - 2s 445ms/step - loss: 1.1980 - accuracy: 0.5570 - val_loss: 1.7024 - val_accuracy: 0.4300
# Epoch 34/100
# 5/5 [==============================] - 3s 502ms/step - loss: 1.1314 - accuracy: 0.6094 - val_loss: 1.7774 - val_accuracy: 0.4200
# Epoch 35/100
# 5/5 [==============================] - 2s 453ms/step - loss: 0.9607 - accuracy: 0.6415 - val_loss: 1.7108 - val_accuracy: 0.4300
# Epoch 36/100
# 5/5 [==============================] - 3s 506ms/step - loss: 1.2640 - accuracy: 0.5500 - val_loss: 2.1781 - val_accuracy: 0.2850
# Epoch 37/100
# 5/5 [==============================] - 2s 452ms/step - loss: 1.1219 - accuracy: 0.5938 - val_loss: 1.7891 - val_accuracy: 0.4000
# Epoch 38/100
# 5/5 [==============================] - 3s 505ms/step - loss: 0.9362 - accuracy: 0.6859 - val_loss: 1.9883 - val_accuracy: 0.3800
# Epoch 39/100
# 5/5 [==============================] - 2s 447ms/step - loss: 1.0481 - accuracy: 0.6085 - val_loss: 1.8460 - val_accuracy: 0.4300
# Epoch 40/100
# 5/5 [==============================] - 3s 511ms/step - loss: 0.8415 - accuracy: 0.7344 - val_loss: 1.9145 - val_accuracy: 0.4250
# Epoch 41/100
# 5/5 [==============================] - 3s 506ms/step - loss: 0.9484 - accuracy: 0.6875 - val_loss: 1.8890 - val_accuracy: 0.4300
# Epoch 42/100
# 5/5 [==============================] - 2s 448ms/step - loss: 0.9933 - accuracy: 0.6324 - val_loss: 1.9464 - val_accuracy: 0.3750
# Epoch 43/100
# 5/5 [==============================] - 2s 448ms/step - loss: 0.7220 - accuracy: 0.7426 - val_loss: 1.8714 - val_accuracy: 0.4600
# Epoch 44/100
# 5/5 [==============================] - 2s 461ms/step - loss: 0.6238 - accuracy: 0.7849 - val_loss: 1.9895 - val_accuracy: 0.4500
# Epoch 45/100
# 5/5 [==============================] - 3s 510ms/step - loss: 0.7613 - accuracy: 0.7484 - val_loss: 1.9318 - val_accuracy: 0.4150
# Epoch 46/100
# 5/5 [==============================] - 2s 449ms/step - loss: 0.6668 - accuracy: 0.7482 - val_loss: 1.9472 - val_accuracy: 0.4500
# Epoch 47/100
# 5/5 [==============================] - 2s 449ms/step - loss: 0.6424 - accuracy: 0.7610 - val_loss: 1.9721 - val_accuracy: 0.4000
# Epoch 48/100
# 5/5 [==============================] - 2s 457ms/step - loss: 0.5261 - accuracy: 0.8254 - val_loss: 2.0589 - val_accuracy: 0.4400
# Epoch 49/100
# 5/5 [==============================] - 2s 451ms/step - loss: 0.7062 - accuracy: 0.7353 - val_loss: 2.0194 - val_accuracy: 0.3700
# Epoch 50/100
# 5/5 [==============================] - 3s 506ms/step - loss: 0.7590 - accuracy: 0.7422 - val_loss: 2.0643 - val_accuracy: 0.4150
# Epoch 51/100
# 5/5 [==============================] - 2s 449ms/step - loss: 0.5715 - accuracy: 0.7794 - val_loss: 1.9149 - val_accuracy: 0.4450
# Epoch 52/100
# 5/5 [==============================] - 2s 456ms/step - loss: 0.5697 - accuracy: 0.7923 - val_loss: 2.0482 - val_accuracy: 0.4200
# Epoch 53/100
# 5/5 [==============================] - 2s 453ms/step - loss: 0.5728 - accuracy: 0.7868 - val_loss: 2.0042 - val_accuracy: 0.3950
# Epoch 54/100
# 5/5 [==============================] - 2s 451ms/step - loss: 0.5573 - accuracy: 0.7868 - val_loss: 2.1259 - val_accuracy: 0.4250
# Epoch 55/100
# 5/5 [==============================] - 2s 447ms/step - loss: 0.4991 - accuracy: 0.8217 - val_loss: 2.0405 - val_accuracy: 0.4000
# Epoch 56/100
# 5/5 [==============================] - 2s 452ms/step - loss: 0.3921 - accuracy: 0.8695 - val_loss: 2.0912 - val_accuracy: 0.4100
# Epoch 57/100
# 5/5 [==============================] - 2s 462ms/step - loss: 0.4966 - accuracy: 0.8346 - val_loss: 2.1485 - val_accuracy: 0.4250
# Epoch 58/100
# 5/5 [==============================] - 2s 455ms/step - loss: 0.4313 - accuracy: 0.8493 - val_loss: 2.1121 - val_accuracy: 0.4550
# Epoch 59/100
# 5/5 [==============================] - 3s 508ms/step - loss: 0.4065 - accuracy: 0.8859 - val_loss: 2.1679 - val_accuracy: 0.4250
# Epoch 60/100
# 5/5 [==============================] - 2s 452ms/step - loss: 0.3751 - accuracy: 0.8640 - val_loss: 2.1939 - val_accuracy: 0.4400
# Epoch 61/100
# 5/5 [==============================] - 2s 454ms/step - loss: 0.3556 - accuracy: 0.8713 - val_loss: 2.3248 - val_accuracy: 0.3850
# Epoch 62/100
# 5/5 [==============================] - 2s 459ms/step - loss: 0.4054 - accuracy: 0.8585 - val_loss: 2.1938 - val_accuracy: 0.4200
# Epoch 63/100
# 5/5 [==============================] - 2s 450ms/step - loss: 0.3066 - accuracy: 0.9062 - val_loss: 2.2331 - val_accuracy: 0.4300
# Epoch 64/100
# 5/5 [==============================] - 2s 448ms/step - loss: 0.5123 - accuracy: 0.8162 - val_loss: 2.3735 - val_accuracy: 0.3700
# Epoch 65/100
# 5/5 [==============================] - 3s 508ms/step - loss: 0.4152 - accuracy: 0.8875 - val_loss: 2.1625 - val_accuracy: 0.4650
# Epoch 66/100
# 5/5 [==============================] - 2s 450ms/step - loss: 0.3642 - accuracy: 0.8787 - val_loss: 2.2511 - val_accuracy: 0.4050
# Epoch 67/100
# 5/5 [==============================] - 2s 450ms/step - loss: 0.2775 - accuracy: 0.9007 - val_loss: 2.3697 - val_accuracy: 0.4050
# Epoch 68/100
# 5/5 [==============================] - 2s 447ms/step - loss: 0.2390 - accuracy: 0.9246 - val_loss: 2.4795 - val_accuracy: 0.4300
# Epoch 69/100
# 5/5 [==============================] - 2s 452ms/step - loss: 0.2822 - accuracy: 0.8989 - val_loss: 2.4656 - val_accuracy: 0.4400
# Epoch 70/100
# 5/5 [==============================] - 2s 451ms/step - loss: 0.2763 - accuracy: 0.9081 - val_loss: 2.3447 - val_accuracy: 0.4200
# Epoch 71/100
# 5/5 [==============================] - 3s 514ms/step - loss: 0.2678 - accuracy: 0.9297 - val_loss: 2.4108 - val_accuracy: 0.4300
# Epoch 72/100
# 5/5 [==============================] - 2s 451ms/step - loss: 0.2503 - accuracy: 0.8971 - val_loss: 2.4370 - val_accuracy: 0.4250
# Epoch 73/100
# 5/5 [==============================] - 2s 453ms/step - loss: 0.2331 - accuracy: 0.9228 - val_loss: 2.4526 - val_accuracy: 0.4100
# Epoch 74/100
# 5/5 [==============================] - 3s 509ms/step - loss: 0.2734 - accuracy: 0.9125 - val_loss: 2.4739 - val_accuracy: 0.4200
# Epoch 75/100
# 5/5 [==============================] - 2s 450ms/step - loss: 0.2143 - accuracy: 0.9228 - val_loss: 2.3830 - val_accuracy: 0.4050
# Epoch 76/100
# 5/5 [==============================] - 3s 513ms/step - loss: 0.3203 - accuracy: 0.8891 - val_loss: 2.3753 - val_accuracy: 0.4150
# Epoch 77/100
# 5/5 [==============================] - 3s 506ms/step - loss: 0.2120 - accuracy: 0.9297 - val_loss: 2.5572 - val_accuracy: 0.4500
# Epoch 78/100
# 5/5 [==============================] - 2s 449ms/step - loss: 0.1746 - accuracy: 0.9449 - val_loss: 2.5335 - val_accuracy: 0.4200
# Epoch 79/100
# 5/5 [==============================] - 2s 446ms/step - loss: 0.1608 - accuracy: 0.9559 - val_loss: 2.5901 - val_accuracy: 0.4350
# Epoch 80/100
# 5/5 [==============================] - 3s 509ms/step - loss: 0.2007 - accuracy: 0.9375 - val_loss: 2.7290 - val_accuracy: 0.4150
# Epoch 81/100
# 5/5 [==============================] - 2s 463ms/step - loss: 0.2205 - accuracy: 0.9118 - val_loss: 2.7377 - val_accuracy: 0.3900
# Epoch 82/100
# 5/5 [==============================] - 2s 455ms/step - loss: 0.1902 - accuracy: 0.9393 - val_loss: 2.6734 - val_accuracy: 0.4150
# Epoch 83/100
# 5/5 [==============================] - 2s 453ms/step - loss: 0.1727 - accuracy: 0.9393 - val_loss: 2.7472 - val_accuracy: 0.4250
# Epoch 84/100
# 5/5 [==============================] - 2s 455ms/step - loss: 0.1766 - accuracy: 0.9283 - val_loss: 2.7832 - val_accuracy: 0.3900
# Epoch 85/100
# 5/5 [==============================] - 3s 506ms/step - loss: 0.2431 - accuracy: 0.9312 - val_loss: 2.5498 - val_accuracy: 0.4250
# Epoch 86/100
# 5/5 [==============================] - 2s 446ms/step - loss: 0.1148 - accuracy: 0.9669 - val_loss: 2.7270 - val_accuracy: 0.4200
# Epoch 87/100
# 5/5 [==============================] - 2s 447ms/step - loss: 0.1714 - accuracy: 0.9467 - val_loss: 2.6518 - val_accuracy: 0.4350
# Epoch 88/100
# 5/5 [==============================] - 2s 448ms/step - loss: 0.1296 - accuracy: 0.9706 - val_loss: 2.7170 - val_accuracy: 0.4350
# Epoch 89/100
# 5/5 [==============================] - 3s 508ms/step - loss: 0.2087 - accuracy: 0.9391 - val_loss: 3.0021 - val_accuracy: 0.4350
# Epoch 90/100
# 5/5 [==============================] - 3s 501ms/step - loss: 0.2146 - accuracy: 0.9281 - val_loss: 2.7286 - val_accuracy: 0.4250
# Epoch 91/100
# 5/5 [==============================] - 3s 505ms/step - loss: 0.1586 - accuracy: 0.9484 - val_loss: 2.7293 - val_accuracy: 0.4000
# Epoch 92/100
# 5/5 [==============================] - 2s 450ms/step - loss: 0.1317 - accuracy: 0.9577 - val_loss: 2.6800 - val_accuracy: 0.4250
# Epoch 93/100
# 5/5 [==============================] - 2s 453ms/step - loss: 0.1398 - accuracy: 0.9577 - val_loss: 2.9603 - val_accuracy: 0.4200
# Epoch 94/100
# 5/5 [==============================] - 3s 502ms/step - loss: 0.1392 - accuracy: 0.9563 - val_loss: 2.7207 - val_accuracy: 0.4150
# Epoch 95/100
# 5/5 [==============================] - 2s 446ms/step - loss: 0.1061 - accuracy: 0.9651 - val_loss: 2.9045 - val_accuracy: 0.4250
# Epoch 96/100
# 5/5 [==============================] - 2s 451ms/step - loss: 0.1587 - accuracy: 0.9412 - val_loss: 2.8755 - val_accuracy: 0.4300
# Epoch 97/100
# 5/5 [==============================] - 2s 446ms/step - loss: 0.1721 - accuracy: 0.9449 - val_loss: 2.9073 - val_accuracy: 0.4050
# Epoch 98/100
# 5/5 [==============================] - 2s 452ms/step - loss: 0.1247 - accuracy: 0.9669 - val_loss: 2.7668 - val_accuracy: 0.4400
# Epoch 99/100
# 5/5 [==============================] - 2s 445ms/step - loss: 0.1068 - accuracy: 0.9724 - val_loss: 2.7844 - val_accuracy: 0.4250
# Epoch 100/100
# 5/5 [==============================] - 3s 505ms/step - loss: 0.1172 - accuracy: 0.9672 - val_loss: 2.8888 - val_accuracy: 0.4000
# Confusion matrix
# [[ 6  1  2  1  3  3  0  0  2  1]
#  [ 0 13  0  1  0  0  0  0  1  1]
#  [ 3  2  4  1  2  3  2  2  0  0]
#  [ 0  1  0  4  0  8  2  1  0  2]
#  [ 3  1  1  3  4  2  5  3  0  1]
#  [ 1  1  1  7  1  7  2  2  1  1]
#  [ 0  0  0  5  2  4  7  1  0  0]
#  [ 1  0  1  3  3  2  1 15  0  0]
#  [ 3  1  0  0  0  0  0  0 12  0]
#  [ 0  5  0  4  0  1  1  0  1  8]]
# Test score: 2.8888104343414307
# Test accuracy: 0.4
# Output results are saved in output_9ca9e996-fb8e-4852-a53b-9d4b9c432444
