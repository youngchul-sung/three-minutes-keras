# %% [markdown]
# <a href="https://colab.research.google.com/github/youngchul-sung/three-minutes-keras/blob/master/ex3_2_dnn_cifar10_cl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 2.x

import os
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers, models, datasets
import matplotlib.pyplot as plt
from sklearn import preprocessing
# Out:
# TensorFlow 2.x selected.

# %%
def save_history_history(fname, history_history, fold=''):
    np.save(os.path.join(fold, fname), history_history)


def load_history_history(fname, fold=''):
    history_history = np.load(os.path.join(fold, fname)).item(0)
    return history_history


def plot_acc(history, title=None):
    # summarize history for accuracy
    if not isinstance(history, dict):
        history = history.history

    plt.plot(history['accuracy'])
    plt.plot(history['val_accuracy'])
    if title is not None:
        plt.title(title)
    plt.ylabel('Accracy')
    plt.xlabel('Epoch')
    plt.legend(['Training data', 'Validation data'], loc=0)
    # plt.show()


def plot_loss(history, title=None):
    # summarize history for loss
    if not isinstance(history, dict):
        history = history.history

    plt.plot(history['loss'])
    plt.plot(history['val_loss'])
    if title is not None:
        plt.title(title)
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Training data', 'Validation data'], loc=0)
    # plt.show()


def plot_history(history):
    plt.figure(figsize=(15, 5))
    plt.subplot(1, 2, 1)
    plot_acc(history)
    plt.subplot(1, 2, 2)
    plot_loss(history)


def plot_loss_acc(history):
    plot_loss(history, '(a) Loss trajectory')
    plt.show()
    plot_acc(history, '(b) Accracy trajectory')
    plt.show()


def plot_acc_loss(history):
    plot_acc(history, '(a) Accracy trajectory')
    plt.show()
    plot_loss(history, '(b) Loss trajectory')
    plt.show()

# %%
class DNN(models.Sequential):
    def __init__(self, Nin, Nh_l, Pd_l, Nout):
        super().__init__()

        self.add(layers.Dense(Nh_l[0], activation='relu',
                              input_shape=(Nin,), name='Hidden-1'))
        self.add(layers.Dropout(Pd_l[0]))

        self.add(layers.Dense(Nh_l[1], activation='relu',
                              name='Hidden-2'))
        self.add(layers.Dropout(Pd_l[1]))

        self.add(layers.Dense(Nout, activation='softmax'))

        self.compile(loss='categorical_crossentropy',
                     optimizer='adam',
                     metrics=['accuracy'])


def Data_func():
    (X_train, y_train), (X_test, y_test) = datasets.cifar10.load_data()

    Y_train = keras.utils.to_categorical(y_train)
    Y_test = keras.utils.to_categorical(y_test)

    L, W, H, C = X_train.shape
    X_train = X_train.reshape(-1, W * H * C)
    X_test = X_test.reshape(-1, W * H * C)

    X_train = X_train / 255.0
    X_test = X_test / 255.0

    return (X_train, Y_train), (X_test, Y_test)


# 분류 DNN 학습 및 테스팅 ####################
def main(Pd_l=[0.0, 0.0]):
    Nh_l = [100, 50]
    number_of_class = 10
    Nout = number_of_class

    (X_train, Y_train), (X_test, Y_test) = Data_func()
    model = DNN(X_train.shape[1], Nh_l, Pd_l, Nout)
    model.summary()
    history = model.fit(X_train, Y_train, epochs=100, batch_size=100, validation_split=0.2)

    performace_test = model.evaluate(X_test, Y_test, batch_size=100)
    print('Test Loss and Accuracy ->', performace_test)

    plot_acc(history, '(a) accuracy over epochs')
    plt.show()
    plot_loss(history, '(b) loss over epochs')
    plt.show()


if __name__ == '__main__':
    main(Pd_l=[0.0, 0.0])
# Out:
# Model: "dnn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Hidden-1 (Dense)             (None, 100)               307300
# _________________________________________________________________
# dropout (Dropout)            (None, 100)               0
# _________________________________________________________________
# Hidden-2 (Dense)             (None, 50)                5050
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense (Dense)                (None, 10)                510
# =================================================================
# Total params: 312,860
# Trainable params: 312,860
# Non-trainable params: 0
# _________________________________________________________________
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/100
# 40000/40000 [==============================] - 2s 55us/sample - loss: 1.9246 - accuracy: 0.3026 - val_loss: 1.8216 - val_accuracy: 0.3466
# Epoch 2/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.7504 - accuracy: 0.3733 - val_loss: 1.7137 - val_accuracy: 0.3877
# Epoch 3/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.6787 - accuracy: 0.3997 - val_loss: 1.6683 - val_accuracy: 0.4133
# Epoch 4/100
# 40000/40000 [==============================] - 2s 40us/sample - loss: 1.6372 - accuracy: 0.4160 - val_loss: 1.6447 - val_accuracy: 0.4171
# Epoch 5/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.6020 - accuracy: 0.4284 - val_loss: 1.6222 - val_accuracy: 0.4248
# Epoch 6/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.5714 - accuracy: 0.4395 - val_loss: 1.6580 - val_accuracy: 0.4132
# Epoch 7/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.5542 - accuracy: 0.4486 - val_loss: 1.6392 - val_accuracy: 0.4225
# Epoch 8/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.5353 - accuracy: 0.4505 - val_loss: 1.5833 - val_accuracy: 0.4404
# Epoch 9/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.5177 - accuracy: 0.4567 - val_loss: 1.5604 - val_accuracy: 0.4500
# Epoch 10/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.5009 - accuracy: 0.4625 - val_loss: 1.5550 - val_accuracy: 0.4475
# Epoch 11/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.4905 - accuracy: 0.4656 - val_loss: 1.5641 - val_accuracy: 0.4486
# Epoch 12/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.4829 - accuracy: 0.4687 - val_loss: 1.6019 - val_accuracy: 0.4321
# Epoch 13/100
# 40000/40000 [==============================] - 2s 42us/sample - loss: 1.4658 - accuracy: 0.4761 - val_loss: 1.5533 - val_accuracy: 0.4458
# Epoch 14/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.4546 - accuracy: 0.4767 - val_loss: 1.5375 - val_accuracy: 0.4506
# Epoch 15/100
# 40000/40000 [==============================] - 2s 42us/sample - loss: 1.4503 - accuracy: 0.4792 - val_loss: 1.5608 - val_accuracy: 0.4500
# Epoch 16/100
# 40000/40000 [==============================] - 2s 42us/sample - loss: 1.4368 - accuracy: 0.4818 - val_loss: 1.5082 - val_accuracy: 0.4627
# Epoch 17/100
# 40000/40000 [==============================] - 2s 42us/sample - loss: 1.4288 - accuracy: 0.4882 - val_loss: 1.5029 - val_accuracy: 0.4644
# Epoch 18/100
# 40000/40000 [==============================] - 2s 42us/sample - loss: 1.4205 - accuracy: 0.4902 - val_loss: 1.5122 - val_accuracy: 0.4619
# Epoch 19/100
# 40000/40000 [==============================] - 2s 42us/sample - loss: 1.4188 - accuracy: 0.4924 - val_loss: 1.5117 - val_accuracy: 0.4656
# Epoch 20/100
# 40000/40000 [==============================] - 2s 42us/sample - loss: 1.4123 - accuracy: 0.4959 - val_loss: 1.5332 - val_accuracy: 0.4586
# Epoch 21/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.4053 - accuracy: 0.4947 - val_loss: 1.5207 - val_accuracy: 0.4616
# Epoch 22/100
# 40000/40000 [==============================] - 2s 42us/sample - loss: 1.3931 - accuracy: 0.5004 - val_loss: 1.5230 - val_accuracy: 0.4646
# Epoch 23/100
# 40000/40000 [==============================] - 2s 40us/sample - loss: 1.3915 - accuracy: 0.5047 - val_loss: 1.5043 - val_accuracy: 0.4687
# Epoch 24/100
# 40000/40000 [==============================] - 2s 40us/sample - loss: 1.3892 - accuracy: 0.5019 - val_loss: 1.5340 - val_accuracy: 0.4613
# Epoch 25/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.3841 - accuracy: 0.5034 - val_loss: 1.4988 - val_accuracy: 0.4710
# Epoch 26/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.3804 - accuracy: 0.5044 - val_loss: 1.5070 - val_accuracy: 0.4649
# Epoch 27/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.3689 - accuracy: 0.5105 - val_loss: 1.5561 - val_accuracy: 0.4474
# Epoch 28/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.3678 - accuracy: 0.5125 - val_loss: 1.5302 - val_accuracy: 0.4650
# Epoch 29/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.3652 - accuracy: 0.5112 - val_loss: 1.5015 - val_accuracy: 0.4688
# Epoch 30/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.3609 - accuracy: 0.5117 - val_loss: 1.4846 - val_accuracy: 0.4774
# Epoch 31/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.3588 - accuracy: 0.5110 - val_loss: 1.5046 - val_accuracy: 0.4709
# Epoch 32/100
# 40000/40000 [==============================] - 2s 40us/sample - loss: 1.3468 - accuracy: 0.5172 - val_loss: 1.5104 - val_accuracy: 0.4697
# Epoch 33/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.3459 - accuracy: 0.5180 - val_loss: 1.4844 - val_accuracy: 0.4743
# Epoch 34/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.3445 - accuracy: 0.5163 - val_loss: 1.5278 - val_accuracy: 0.4653
# Epoch 35/100
# 40000/40000 [==============================] - 2s 44us/sample - loss: 1.3359 - accuracy: 0.5222 - val_loss: 1.5036 - val_accuracy: 0.4698
# Epoch 36/100
# 40000/40000 [==============================] - 2s 44us/sample - loss: 1.3348 - accuracy: 0.5219 - val_loss: 1.4949 - val_accuracy: 0.4724
# Epoch 37/100
# 40000/40000 [==============================] - 2s 44us/sample - loss: 1.3313 - accuracy: 0.5228 - val_loss: 1.4957 - val_accuracy: 0.4772
# Epoch 38/100
# 40000/40000 [==============================] - 2s 43us/sample - loss: 1.3274 - accuracy: 0.5213 - val_loss: 1.5496 - val_accuracy: 0.4551
# Epoch 39/100
# 40000/40000 [==============================] - 2s 44us/sample - loss: 1.3310 - accuracy: 0.5192 - val_loss: 1.4923 - val_accuracy: 0.4808
# Epoch 40/100
# 40000/40000 [==============================] - 2s 43us/sample - loss: 1.3159 - accuracy: 0.5264 - val_loss: 1.4963 - val_accuracy: 0.4729
# Epoch 41/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.3192 - accuracy: 0.5279 - val_loss: 1.5245 - val_accuracy: 0.4632
# Epoch 42/100
# 40000/40000 [==============================] - 2s 40us/sample - loss: 1.3144 - accuracy: 0.5295 - val_loss: 1.5149 - val_accuracy: 0.4644
# Epoch 43/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.3184 - accuracy: 0.5253 - val_loss: 1.4903 - val_accuracy: 0.4796
# Epoch 44/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.3114 - accuracy: 0.5296 - val_loss: 1.4994 - val_accuracy: 0.4738
# Epoch 45/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.3044 - accuracy: 0.5297 - val_loss: 1.5131 - val_accuracy: 0.4658
# Epoch 46/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.3006 - accuracy: 0.5311 - val_loss: 1.5377 - val_accuracy: 0.4618
# Epoch 47/100
# 40000/40000 [==============================] - 2s 40us/sample - loss: 1.3050 - accuracy: 0.5334 - val_loss: 1.4878 - val_accuracy: 0.4765
# Epoch 48/100
# 40000/40000 [==============================] - 2s 40us/sample - loss: 1.2975 - accuracy: 0.5354 - val_loss: 1.5138 - val_accuracy: 0.4689
# Epoch 49/100
# 40000/40000 [==============================] - 2s 40us/sample - loss: 1.2942 - accuracy: 0.5361 - val_loss: 1.5066 - val_accuracy: 0.4763
# Epoch 50/100
# 40000/40000 [==============================] - 2s 40us/sample - loss: 1.2924 - accuracy: 0.5364 - val_loss: 1.4820 - val_accuracy: 0.4802
# Epoch 51/100
# 40000/40000 [==============================] - 2s 40us/sample - loss: 1.2953 - accuracy: 0.5331 - val_loss: 1.4781 - val_accuracy: 0.4803
# Epoch 52/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.2870 - accuracy: 0.5359 - val_loss: 1.4904 - val_accuracy: 0.4770
# Epoch 53/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.2849 - accuracy: 0.5361 - val_loss: 1.4805 - val_accuracy: 0.4803
# Epoch 54/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.2896 - accuracy: 0.5346 - val_loss: 1.5080 - val_accuracy: 0.4828
# Epoch 55/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.2777 - accuracy: 0.5397 - val_loss: 1.5096 - val_accuracy: 0.4690
# Epoch 56/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.2775 - accuracy: 0.5398 - val_loss: 1.5099 - val_accuracy: 0.4772
# Epoch 57/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.2762 - accuracy: 0.5415 - val_loss: 1.4890 - val_accuracy: 0.4826
# Epoch 58/100
# 40000/40000 [==============================] - 2s 40us/sample - loss: 1.2747 - accuracy: 0.5404 - val_loss: 1.4956 - val_accuracy: 0.4739
# Epoch 59/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.2780 - accuracy: 0.5405 - val_loss: 1.5190 - val_accuracy: 0.4724
# Epoch 60/100
# 40000/40000 [==============================] - 2s 42us/sample - loss: 1.2642 - accuracy: 0.5447 - val_loss: 1.5219 - val_accuracy: 0.4700
# Epoch 61/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.2665 - accuracy: 0.5457 - val_loss: 1.5091 - val_accuracy: 0.4742
# Epoch 62/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.2683 - accuracy: 0.5430 - val_loss: 1.5413 - val_accuracy: 0.4715
# Epoch 63/100
# 40000/40000 [==============================] - 2s 42us/sample - loss: 1.2673 - accuracy: 0.5442 - val_loss: 1.4999 - val_accuracy: 0.4836
# Epoch 64/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.2570 - accuracy: 0.5487 - val_loss: 1.5463 - val_accuracy: 0.4677
# Epoch 65/100
# 40000/40000 [==============================] - 2s 42us/sample - loss: 1.2571 - accuracy: 0.5476 - val_loss: 1.5003 - val_accuracy: 0.4781
# Epoch 66/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.2568 - accuracy: 0.5472 - val_loss: 1.5200 - val_accuracy: 0.4680
# Epoch 67/100
# 40000/40000 [==============================] - 2s 40us/sample - loss: 1.2588 - accuracy: 0.5486 - val_loss: 1.5060 - val_accuracy: 0.4803
# Epoch 68/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.2539 - accuracy: 0.5504 - val_loss: 1.4901 - val_accuracy: 0.4849
# Epoch 69/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.2501 - accuracy: 0.5484 - val_loss: 1.5359 - val_accuracy: 0.4701
# Epoch 70/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.2469 - accuracy: 0.5545 - val_loss: 1.4981 - val_accuracy: 0.4801
# Epoch 71/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.2476 - accuracy: 0.5504 - val_loss: 1.5267 - val_accuracy: 0.4725
# Epoch 72/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.2454 - accuracy: 0.5529 - val_loss: 1.5105 - val_accuracy: 0.4752
# Epoch 73/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.2444 - accuracy: 0.5511 - val_loss: 1.5361 - val_accuracy: 0.4711
# Epoch 74/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.2446 - accuracy: 0.5529 - val_loss: 1.4955 - val_accuracy: 0.4789
# Epoch 75/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.2397 - accuracy: 0.5555 - val_loss: 1.5148 - val_accuracy: 0.4790
# Epoch 76/100
# 40000/40000 [==============================] - 2s 40us/sample - loss: 1.2415 - accuracy: 0.5556 - val_loss: 1.5019 - val_accuracy: 0.4788
# Epoch 77/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.2341 - accuracy: 0.5536 - val_loss: 1.4862 - val_accuracy: 0.4878
# Epoch 78/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.2323 - accuracy: 0.5566 - val_loss: 1.5523 - val_accuracy: 0.4668
# Epoch 79/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.2427 - accuracy: 0.5541 - val_loss: 1.5441 - val_accuracy: 0.4646
# Epoch 80/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.2318 - accuracy: 0.5561 - val_loss: 1.5177 - val_accuracy: 0.4744
# Epoch 81/100
# 40000/40000 [==============================] - 2s 42us/sample - loss: 1.2329 - accuracy: 0.5599 - val_loss: 1.5313 - val_accuracy: 0.4760
# Epoch 82/100
# 40000/40000 [==============================] - 2s 40us/sample - loss: 1.2270 - accuracy: 0.5583 - val_loss: 1.5246 - val_accuracy: 0.4764
# Epoch 83/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.2267 - accuracy: 0.5571 - val_loss: 1.5202 - val_accuracy: 0.4759
# Epoch 84/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.2282 - accuracy: 0.5589 - val_loss: 1.5440 - val_accuracy: 0.4740
# Epoch 85/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.2225 - accuracy: 0.5581 - val_loss: 1.5257 - val_accuracy: 0.4799
# Epoch 86/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.2201 - accuracy: 0.5591 - val_loss: 1.5063 - val_accuracy: 0.4730
# Epoch 87/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.2201 - accuracy: 0.5596 - val_loss: 1.5250 - val_accuracy: 0.4765
# Epoch 88/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.2268 - accuracy: 0.5559 - val_loss: 1.5545 - val_accuracy: 0.4651
# Epoch 89/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.2139 - accuracy: 0.5646 - val_loss: 1.5132 - val_accuracy: 0.4824
# Epoch 90/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.2161 - accuracy: 0.5612 - val_loss: 1.5333 - val_accuracy: 0.4772
# Epoch 91/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.2157 - accuracy: 0.5632 - val_loss: 1.5705 - val_accuracy: 0.4597
# Epoch 92/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.2136 - accuracy: 0.5629 - val_loss: 1.5226 - val_accuracy: 0.4755
# Epoch 93/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.2152 - accuracy: 0.5623 - val_loss: 1.5756 - val_accuracy: 0.4693
# Epoch 94/100
# 40000/40000 [==============================] - 2s 40us/sample - loss: 1.2050 - accuracy: 0.5642 - val_loss: 1.5449 - val_accuracy: 0.4744
# Epoch 95/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.2110 - accuracy: 0.5669 - val_loss: 1.5309 - val_accuracy: 0.4731
# Epoch 96/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.2105 - accuracy: 0.5628 - val_loss: 1.5103 - val_accuracy: 0.4815
# Epoch 97/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.2091 - accuracy: 0.5642 - val_loss: 1.5580 - val_accuracy: 0.4768
# Epoch 98/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.2066 - accuracy: 0.5652 - val_loss: 1.5541 - val_accuracy: 0.4680
# Epoch 99/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.1988 - accuracy: 0.5669 - val_loss: 1.5177 - val_accuracy: 0.4819
# Epoch 100/100
# 40000/40000 [==============================] - 2s 41us/sample - loss: 1.2025 - accuracy: 0.5685 - val_loss: 1.5652 - val_accuracy: 0.4766
# 10000/10000 [==============================] - 0s 29us/sample - loss: 1.5365 - accuracy: 0.4778
# Test Loss and Accuracy -> [1.53652383685112, 0.4778]
